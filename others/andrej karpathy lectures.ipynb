# %%
a=2
c=3
z = a+c
print(z)
# Out:
# 5

# %%
def f(x):
    return 3*x**2 - 2*x + 7
f(3)
# Out:
# 28

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-10, 10, 0.1)
plt.plot(x, f(x))
